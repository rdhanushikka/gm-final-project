# %% [markdown]
# <a href="https://colab.research.google.com/github/rdhanushikka/gm-final-project/blob/main/lora_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate peft torch torchvision
# !pip install -q -r /content/diffusers/examples/dreambooth/requirements.txt
# Out:
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/diffusers/examples/dreambooth/requirements.txt'

# %%
# !git clone https://github.com/huggingface/diffusers.git
# !git clone https://github.com/rdhanushikka/gm-final-project.git
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 121141, done.
# remote: Counting objects: 100% (640/640), done.
# remote: Compressing objects: 100% (338/338), done.
# remote: Total 121141 (delta 516), reused 302 (delta 302), pack-reused 120501 (from 3)
# Receiving objects: 100% (121141/121141), 94.57 MiB | 13.25 MiB/s, done.
# Resolving deltas: 100% (90143/90143), done.
# Cloning into 'gm-final-project'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 72 (delta 5), reused 69 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 13.06 MiB | 19.25 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !git clone https://github.com/rdhanushikka/gm-final-project.git
# Out:
# fatal: destination path 'gm-final-project' already exists and is not an empty directory.

# %%
# !git -C /content/gm-final-project pull
# Out:
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 34 (delta 3), reused 34 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (34/34), 6.78 MiB | 11.96 MiB/s, done.
# From https://github.com/rdhanushikka/gm-final-project
#    b4cf80e..2bad408  main       -> origin/main
# Updating b4cf80e..2bad408
# Fast-forward
#  .gitignore                                     |  23 +++++++
#  README.md                                      |  89 ++++++++++++++++++++++++-
#  data/captions/image_01.txt                     |   2 +-
#  data/captions/image_02.txt                     |   2 +-
#  data/captions/image_03.txt                     |   2 +-
#  data/captions/image_04.txt                     |   2 +-
#  data/captions/image_05.txt                     |   2 +-
#  data/captions/image_06.txt                     |   2 +-
#  data/captions/image_07.txt                     |   2 +-
# ...

# %%
# !ls /content/gm-final-project/data/images/
# Out:
# image_01.png  image_05.png  image_09.png  image_13.png  image_17.png
# image_02.png  image_06.png  image_10.png  image_14.png  image_18.png
# image_03.png  image_07.png  image_11.png  image_15.png
# image_04.png  image_08.png  image_12.png  image_16.png

# %%
# !pip install -q diffusers transformers accelerate peft torch torchvision
# !pip install -q -r diffusers/examples/dreambooth/requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00

# %%
# !pip install -q --upgrade peft diffusers
# !pip install -e /content/diffusers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 10.1 MB/s eta 0:00:00

# %% [markdown]
# To resolve this, we will uninstall the currently installed `diffusers` library and then install it from the source code that was previously cloned.

# %%
# !pip uninstall -y diffusers
# !pip install -e /content/diffusers
# Out:
# Found existing installation: diffusers 0.37.1
# Uninstalling diffusers-0.37.1:
#   Successfully uninstalled diffusers-0.37.1
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.1/509.1 kB 9.1 MB/s eta 0:00:00
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.38.0.dev0-0.editable-py3-none-any.whl size=11406 sha256=2357eb822b3e61c4ba4cbf0b51de39fe32c2cd818337e4b63119483e186bbb88
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wsc5nett/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
# ...

# %%
# !pip install --upgrade torchao
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121 --force-reinstall --no-cache-dir
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 238.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 356.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 322.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 436.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 335.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 235.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 259.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 274.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 288.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 258.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 183.2 MB/s eta 0:00:00
# ...

# %%
  # !git clone https://github.com/huggingface/diffusers.git
  # !pip install -e /content/diffusers
# Out:
# fatal: destination path 'diffusers' already exists and is not an empty directory.
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.1/509.1 kB 42.4 MB/s eta 0:00:00
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.38.0.dev0-0.editable-py3-none-any.whl size=11406 sha256=c7ce37d71bc1f014206b366bb49c544b66732c0a0fdd1b7f77215d462ca329c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-itvuzfb2/wheels/8a/fc/09/385efb77b455b2fd4a656c950079c93147e1f50ae614e51beb
# Successfully built diffusers
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
# ...

# %%
  # !pip install peft accelerate transformers

# %%
import torch
print(torch.cuda.is_available())  # must be True before training
# Out:
# True

# %%
# !accelerate launch /content/diffusers/examples/dreambooth/train_dreambooth_lora.py \
    --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
    --instance_data_dir="/content/gm-final-project/data/images" \
    --instance_prompt="a photo of <zendaya> person" \
    --output_dir="/content/results/lora" \
    --train_batch_size=1 \
    --num_train_epochs=20 \
    --learning_rate=5e-5 \
    --mixed_precision="fp16" \
    --resolution=512
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !nvidia-smi
# Out:
# Sun Apr 26 00:17:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install /content/diffusers --force-reinstall
# Out:
# Processing ./diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.7 MB/s eta 0:00:00
# ...
#   Using cached safetensors-0.8.0rc0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.8/646.8 kB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.1/801.1 kB 58.2 MB/s eta 0:00:00
# Using cached safetensors-0.8.0rc0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (509 kB)
# ...

# %%
# !python /content/gm-final-project/lora/train.py \
    --data_dir /content/gm-final-project/data/images \
    --caption_dir /content/gm-final-project/data/captions \
    --output_dir /content/drive/MyDrive/results/lora_custom \
    --num_epochs 20 \
    --learning_rate 5e-5

# %%
print(pipe.get_active_adapters())
# Out:
# ['default_0']

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float32,
    safety_checker=None
).to("cuda")

prompts = [
      "a close-up portrait of <zendaya> person smiling",
      "a close-up portrait of <zendaya> person with curly hair",
      "a close-up portrait of <zendaya> person outdoors in sunlight",
      "a studio headshot of <zendaya> person",
      "a close-up portrait of <zendaya> person with a neutral expression",
  ]

# Without LoRA
for i, prompt in enumerate(prompts):
    image = pipe(
        prompt,
        negative_prompt="full body, cropped face, low quality, blurry",
        num_inference_steps=30,
        guidance_scale=7.5
    ).images[0]
    image.save(f"/content/results/lora/baseline_{i+1}.png")
    print(f"Saved baseline_{i+1}.png")

# With LoRA
pipe.load_lora_weights("/content/results/lora")

for i, prompt in enumerate(prompts):
    image = pipe(
        prompt,
        negative_prompt="full body, cropped face, low quality, blurry",
        num_inference_steps=30,
        guidance_scale=7.5
    ).images[0]
    image.save(f"/content/results/lora/lora_{i+1}.png")
    print(f"Saved lora_{i+1}.png")
# Out:
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...
